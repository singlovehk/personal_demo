# %%
import numpy as np
import pandas as pd 
import sklearn
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from lightgbm import LGBMRegressor
import keras
from keras import Sequential
from keras.layers import Dense, Dropout
import pickle
# Out:
# Using TensorFlow backend.
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data = pd.read_pickle('data.pkl')

# %%
data = data[[
    'date_block_num',
    'shop_id',
    'item_id',
    'item_cnt_month',
    'city_code',
    'item_category_id',
    'type_code',
    'subtype_code',
    'item_cnt_month_lag_1',
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3',
    'item_cnt_month_lag_6',
    'item_cnt_month_lag_12',
    'date_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_2',
    'date_item_avg_item_cnt_lag_3',
    'date_item_avg_item_cnt_lag_6',
    'date_item_avg_item_cnt_lag_12',
    'date_shop_avg_item_cnt_lag_1',
    'date_shop_avg_item_cnt_lag_2',
    'date_shop_avg_item_cnt_lag_3',
    'date_shop_avg_item_cnt_lag_6',
    'date_shop_avg_item_cnt_lag_12',
    'date_cat_avg_item_cnt_lag_1',
    'date_shop_cat_avg_item_cnt_lag_1',
    #'date_shop_type_avg_item_cnt_lag_1',
    #'date_shop_subtype_avg_item_cnt_lag_1',
    'date_city_avg_item_cnt_lag_1',
    'date_item_city_avg_item_cnt_lag_1',
    #'date_type_avg_item_cnt_lag_1',
    #'date_subtype_avg_item_cnt_lag_1',
    'delta_price_lag',
    'month',
    'days',
    'item_shop_last_sale',
    'item_last_sale',
    'item_shop_first_sale',
    'item_first_sale',
]]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
model = xgb.XGBRegressor(
    max_depth=7,
    n_estimators=200,
    min_child_weight=300,  
    subsample=0.8, 
    eta=0.3)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\starm\Anaconda3\envs\py3.6\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [13:43:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:44:00] WARNING: C:\Jenkins\workspace\xgboost-win64_release_0.90\src\learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.15313	validation_1-rmse:1.11941
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.10749	validation_1-rmse:1.0853
# [2]	validation_0-rmse:1.06874	validation_1-rmse:1.05716
# [3]	validation_0-rmse:1.03566	validation_1-rmse:1.03265
# [4]	validation_0-rmse:1.0078	validation_1-rmse:1.01402
# [5]	validation_0-rmse:0.983782	validation_1-rmse:0.995921
# [6]	validation_0-rmse:0.963524	validation_1-rmse:0.981094
# [7]	validation_0-rmse:0.946763	validation_1-rmse:0.970664
# [8]	validation_0-rmse:0.932116	validation_1-rmse:0.960798
# [9]	validation_0-rmse:0.920045	validation_1-rmse:0.953048
# [10]	validation_0-rmse:0.909592	validation_1-rmse:0.946483
# [11]	validation_0-rmse:0.900918	validation_1-rmse:0.942236
# [12]	validation_0-rmse:0.893096	validation_1-rmse:0.937142
# [13]	validation_0-rmse:0.886841	validation_1-rmse:0.934228
# [14]	validation_0-rmse:0.881407	validation_1-rmse:0.931588
# [15]	validation_0-rmse:0.876797	validation_1-rmse:0.929421
# [16]	validation_0-rmse:0.872487	validation_1-rmse:0.927044
# [17]	validation_0-rmse:0.868519	validation_1-rmse:0.925384
# [18]	validation_0-rmse:0.864715	validation_1-rmse:0.923804
# [19]	validation_0-rmse:0.86175	validation_1-rmse:0.922868
# [20]	validation_0-rmse:0.859098	validation_1-rmse:0.921661
# [21]	validation_0-rmse:0.856715	validation_1-rmse:0.921295
# [22]	validation_0-rmse:0.854739	validation_1-rmse:0.920729
# [23]	validation_0-rmse:0.853008	validation_1-rmse:0.920004
# [24]	validation_0-rmse:0.850986	validation_1-rmse:0.919338
# [25]	validation_0-rmse:0.84942	validation_1-rmse:0.919014
# [26]	validation_0-rmse:0.8481	validation_1-rmse:0.918699
# [27]	validation_0-rmse:0.846739	validation_1-rmse:0.918568
# [28]	validation_0-rmse:0.845453	validation_1-rmse:0.918788
# [29]	validation_0-rmse:0.844357	validation_1-rmse:0.918235
# [30]	validation_0-rmse:0.843164	validation_1-rmse:0.918122
# [31]	validation_0-rmse:0.841929	validation_1-rmse:0.918423
# [32]	validation_0-rmse:0.841119	validation_1-rmse:0.918369
# [33]	validation_0-rmse:0.839893	validation_1-rmse:0.918339
# [34]	validation_0-rmse:0.838937	validation_1-rmse:0.919264
# [35]	validation_0-rmse:0.838079	validation_1-rmse:0.91972
# [36]	validation_0-rmse:0.837556	validation_1-rmse:0.91968
# [37]	validation_0-rmse:0.836828	validation_1-rmse:0.919695
# [38]	validation_0-rmse:0.836231	validation_1-rmse:0.91989
# [39]	validation_0-rmse:0.835749	validation_1-rmse:0.919568
# [40]	validation_0-rmse:0.835209	validation_1-rmse:0.919375
# Stopping. Best iteration:
# [30]	validation_0-rmse:0.843164	validation_1-rmse:0.918122
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, eta=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=7, min_child_weight=300, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.8, verbosity=1)

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission.csv', index=False)

# %%
test = pd.read_csv('test.csv.gz')

# %%
submission
# Out:
#             ID  item_cnt_month
# 0            0        0.502400
# 1            1        0.501746
# 2            2        1.054313
# 3            3        0.452041
# 4            4        3.820801
# 5            5        0.612646
# 6            6        1.164289
# 7            7        0.152276
# 8            8        0.896934
# 9            9        0.882726
# 10          10        2.473331
# 11          11        0.217385
# 12          12        0.138722
# 13          13        0.382015
# 14          14        1.707920
# 15          15        3.129111
# 16          16        0.045777
# 17          17        0.178995
# 18          18        1.342319
# 19          19        0.290254
# 20          20        0.408083
# 21          21        0.239468
# 22          22        1.591978
# 23          23        0.456065
# 24          24        1.475069
# 25          25        0.965081
# 26          26        0.445713
# 27          27        0.355215
# 28          28        1.144953
# 29          29        4.141307
# ...        ...             ...
# 214170  214170        0.033834
# 214171  214171        0.054779
# 214172  214172        0.053754
# 214173  214173        0.171881
# 214174  214174        0.055591
# 214175  214175        0.054779
# 214176  214176        0.033834
# 214177  214177        0.061020
# 214178  214178        0.053754
# 214179  214179        0.054779
# 214180  214180        0.102037
# 214181  214181        0.132513
# 214182  214182        0.052361
# 214183  214183        0.033834
# 214184  214184        0.033834
# 214185  214185        0.053754
# 214186  214186        0.048855
# 214187  214187        0.133985
# 214188  214188        0.041100
# 214189  214189        0.095583
# 214190  214190        0.068874
# 214191  214191        0.069899
# 214192  214192        0.069899
# 214193  214193        0.084143
# 214194  214194        0.046779
# 214195  214195        0.126131
# 214196  214196        0.042702
# 214197  214197        0.071950
# 214198  214198        0.041100
# 214199  214199        0.066700
#
# [214200 rows x 2 columns]
